# %% [markdown]
# <a href="https://colab.research.google.com/github/surzedo/curso/blob/master/C%C3%B3pia_de_ENEM2016.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

enem16CA = pd.read_csv('/content/drive/My Drive/ColabPython/ENEM16RJ.csv', encoding='latin1', sep=';') #error_bad_lines=False

#enem16CA_top = enem16CA.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
enem16CA.head(10)
# Out:
#    NU_INSCRICAO  NU_ANO  ...  QCL_3              QCL_4
# 0  160000434221    2016  ...      1   ,322411445569094
# 1  160000434237    2016  ...      1    ,41259676593156
# 2  160000437576    2016  ...      2   ,236224517224838
# 3  160000447749    2016  ...      5    ,06967746890782
# 4  160000401738    2016  ...      3   ,172032682681486
# 5  160000417403    2016  ...      1  ,0621374827558085
# 6  160000417412    2016  ...      1   ,302641940391898
# 7  160000424104    2016  ...      3   ,124853780776689
# 8  160000430916    2016  ...      2  ,0694055669536304
# 9  160000401752    2016  ...      5  ,0864548697657611
#
# [10 rows x 103 columns]

# %%
enem16CA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104921 entries, 0 to 104920
# Columns: 103 entries, NU_INSCRICAO to QCL_4
# dtypes: int64(75), object(28)
# memory usage: 82.4+ MB

# %%
total_rows = enem16CA.count
print (total_rows)
# Out:
# <bound method DataFrame.count of         NU_INSCRICAO  NU_ANO  ...  QCL_3              QCL_4
# 0       160000434221    2016  ...      1   ,322411445569094
# 1       160000434237    2016  ...      1    ,41259676593156
# 2       160000437576    2016  ...      2   ,236224517224838
# 3       160000447749    2016  ...      5    ,06967746890782
# 4       160000401738    2016  ...      3   ,172032682681486
# ...              ...     ...  ...    ...                ...
# 104916  160008606896    2016  ...      5   ,154892006807529
# 104917  160008605303    2016  ...      2   ,205486191549306
# 104918  160008458982    2016  ...      5  ,0700430084697267
# 104919  160008574952    2016  ...      5   ,297679278340807
# 104920  160008483775    2016  ...      5   ,211988088607354
#
# [104921 rows x 103 columns]>

# %%
sum(pd.isnull(enem16CA['Q006']))
# Out:
# 0

# %%
# iterating the columns 
for col in enem16CA_top.columns: 
    print(col)
# Out:
# NU_INSCRICAO
# NU_ANO
# CO_MUNICIPIO_RESIDENCIA
# NO_MUNICIPIO_RESIDENCIA
# CO_UF_RESIDENCIA
# SG_UF_RESIDENCIA
# NU_IDADE
# TP_SEXO
# TP_ESTADO_CIVIL
# TP_COR_RACA
# TP_NACIONALIDADE
# CO_MUNICIPIO_NASCIMENTO
# NO_MUNICIPIO_NASCIMENTO
# CO_UF_NASCIMENTO
# SG_UF_NASCIMENTO
# TP_ST_CONCLUSAO
# TP_ANO_CONCLUIU
# TP_ESCOLA
# TP_ENSINO
# IN_TREINEIRO
# CO_ESCOLA
# CO_MUNICIPIO_ESC
# NO_MUNICIPIO_ESC
# CO_UF_ESC
# SG_UF_ESC
# TP_DEPENDENCIA_ADM_ESC
# TP_LOCALIZACAO_ESC
# TP_SIT_FUNC_ESC
# IN_BAIXA_VISAO
# IN_CEGUEIRA
# IN_SURDEZ
# IN_DEFICIENCIA_AUDITIVA
# IN_SURDO_CEGUEIRA
# IN_DEFICIENCIA_FISICA
# IN_DEFICIENCIA_MENTAL
# IN_DEFICIT_ATENCAO
# IN_DISLEXIA
# IN_DISCALCULIA
# IN_AUTISMO
# IN_VISAO_MONOCULAR
# IN_OUTRA_DEF
# IN_SABATISTA
# IN_GESTANTE
# IN_LACTANTE
# IN_IDOSO
# IN_ESTUDA_CLASSE_HOSPITALAR
# IN_SEM_RECURSO
# IN_BRAILLE
# IN_AMPLIADA_24
# IN_AMPLIADA_18
# IN_LEDOR
# IN_ACESSO
# IN_TRANSCRICAO
# IN_LIBRAS
# IN_LEITURA_LABIAL
# IN_MESA_CADEIRA_RODAS
# IN_MESA_CADEIRA_SEPARADA
# ...

# %%
enem16CA['Q006']
# Out:
# 0         1
# 1         1
# 2         1
# 3         3
# 4         6
#          ..
# 104916    1
# 104917    1
# 104918    3
# 104919    2
# 104920    3
# Name: Q006, Length: 104921, dtype: int64

# %%
enem16CA['Q006'].count()
# Out:
# 104921

# %%
enem16CA['Q006'].value_counts()
# Out:
# 3    25215
# 1    16626
# 2    15275
# 4    13361
# 5    10496
# 7     7641
# 6     6721
# 8     5401
# 9     4185
# Name: Q006, dtype: int64

# %%
prop_NR = enem16CA[enem16CA.Q006 == "Nenhuma renda"].count()[0]/enem16CA['Q006'].count()
prop_3 = enem16CA[enem16CA.Q006 == "De R$ 1.320,01 até R$ 1.760,00"].count()[0]/enem16CA['Q006'].count()
prop_4 = enem16CA[enem16CA.Q006 == "De R$ 1.760,01 até R$ 2.200,00"].count()[0]/enem16CA['Q006'].count()
prop_6 = enem16CA[enem16CA.Q006 == "De R$ 2.640,01 até R$ 3.520,00"].count()[0]/enem16CA['Q006'].count()
prop_5 = enem16CA[enem16CA.Q006 == "De R$ 2.200,01 até R$ 2.640,00"].count()[0]/enem16CA['Q006'].count()
prop_7 = enem16CA[enem16CA.Q006 == "De R$ 3.520,01 até R$ 4.400,00"].count()[0]/enem16CA['Q006'].count()
prop_8 = enem16CA[enem16CA.Q006 == "De R$ 4.400,01 até R$ 5.280,00"].count()[0]/enem16CA['Q006'].count()
prop_1 = enem16CA[enem16CA.Q006 == "Até R$ 880,00"].count()[0]/enem16CA['Q006'].count()
prop_2 = enem16CA[enem16CA.Q006 == "De R$ 880,01,01 até R$ 1.320,00"].count()[0]/enem16CA['Q006'].count()

# %%
enem16CA.isnull().any()
# Out:
# NU_INSCRICAO                          False
# NU_ANO                                False
# CO_MUNICIPIO_RESIDENCIA               False
# NO_MUNICIPIO_RESIDENCIA               False
# CO_UF_RESIDENCIA                      False
#                                       ...
# Eixo1_analise_correspondencia_mult    False
# QCL_1                                 False
# QCL_2                                 False
# QCL_3                                 False
# QCL_4                                 False
# Length: 103, dtype: bool

# %%
print(prop_NR)
print(prop_1)
print(prop_2)
print(prop_3)
print(prop_4)
print(prop_5)
print(prop_6)
print(prop_0)
print(prop_00)
# Out:
# 0.0
# 0.14558572640367515
# 0.24032367209614852
# 0.12734342981862545
# 0.10003717082376264
# 0.06405771961761707
# 0.07282622163341942
# 0.14558572640367515
# 0.24032367209614852

# %%
enem16CA['MEDIA_GERAL'].dtype
# Out:
# dtype('O')

# %%
enem16CA['MEDIA_GERAL'] = enem16CA['MEDIA_GERAL'].str.replace(',','.').astype(float)

# %%
plt.hist(enem16CA['MEDIA_GERAL'])
# Out:
# (array([2.0000e+00, 1.2000e+01, 3.4000e+01, 1.0890e+03, 1.4713e+04,
#         4.3559e+04, 2.8169e+04, 1.2916e+04, 4.1720e+03, 2.5500e+02]),
#  array([ 65.62 , 144.278, 222.936, 301.594, 380.252, 458.91 , 537.568,
#         616.226, 694.884, 773.542, 852.2  ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns
sns.distplot(enem16CA['MEDIA_GERAL'])

# %%
plt.figure(figsize=(14,9))
sns.barplot(x='Q006',y='MEDIA_GERAL',data=enem16CA, )

# %%
plt.figure(figsize=(14,9))
sns.boxplot(x='Q006',y='MEDIA_GERAL', data=enem16CA,palette='rainbow')
